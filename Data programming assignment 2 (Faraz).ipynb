# %%
# Question 1
a = 0

def b():
    global a
    a = c(a)
    
def c(a):
    return a + 2

# %%
b()
#when b() is called, it calls the function 'c' and increases the value of a by 2
#at this point the value of a is 2
print(f"1: {a}")
b()
#when it is called again, it against increases a by 2
#here, the value of a is 4
print(f"2:{a}")
b()
#this happens again and the value of a reaches 6
print(f"3: {a}")
a
#6 is printed as the value of a
# Out:
# 1: 2
# 2:4
# 3: 6
# 6

# %%
# Question 2

# %%
def filelength(file_name):
    try:
        file = open(file_name)
    except:
        print(f"File {file_name} not found.")
    else:
        contents = file.read()
        print(len(contents))

# %%
filelength("C:\\Users\\fzzrx\\Downloads\\Filelength.txt")
# Out:
# 123

# %%
filelength('idterm.py')
# Out:
# File idterm.py not found.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Marsupial:          
    def __init__(self,x,y):             
        self.pouch=[]                        
    def put_in_pouch(self,items): 
        self.pouch.append(items)   
    def pouch_contents(self):          
        return self.pouch

class Kangaroo(Marsupial):              
    def __init__(self,x,y):              
        super().__init__(x,y)          
        self.dx = 0                      
        self.dy = 0                        
    def jump(self,x,y):                 
        self.dx = self.dx + x                
        self.dy = self.dy + y
    def __str__(self):           
        return(f"I'm a Kangaroo located at the coordinates {self.dx},{self.dy}.")

# %%
kang = Kangaroo(0,0)

# %%
print(kang)
# Out:
# I'm a Kangaroo located at the coordinates 0,0.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kang.put_in_pouch('doll')
kang.put_in_pouch('firetruck')
kang.put_in_pouch('kitten')
kang.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def collatz(x):
    print(round(x))
    if(x==1):
        return 1
    elif(x%2==0):
        return collatz(x/2)
    elif(x%2!=0):
        return collatz(3*x+1)
collatz(1)
collatz(10)
# Out:
# 1
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def binary (n):
    if n < 2:
        print (n)
    else:
        x='{0:b}'.format(n)
        print(x)
binary(0)
binary(1)
binary(3)
binary(9)
# Out:
# 0
# 1
# 11
# 1001

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sqlite3
con = sqlite3.connect('DBfile.db')
cur = con.cursor()
cur.execute("CREATE TABLE Weatherr (City text, Country text, Season text,Temperature float,Rainfall float)")
cur.execute("INSERT INTO Weatherr VALUES ('Mumbai', 'India', 'Winter',24.8,5.9)")
cur.execute("INSERT INTO Weatherr VALUES ('Mumbai', 'India', 'Spring',28.4,16.2)")
cur.execute("INSERT INTO Weatherr VALUES ('Mumbai', 'India', 'Summer',27.9,1549.4 )")
cur.execute("INSERT INTO Weatherr VALUES ('Mumbai', 'India', 'Fall',27.6,346.0)")
cur.execute("INSERT INTO Weatherr VALUES ('London', 'United Kingdom', 'Winter',4.2,207.7 )")
cur.execute("INSERT INTO Weatherr VALUES ('London', 'United Kingdom', 'Spring',8.3,169.6)")
cur.execute("INSERT INTO Weatherr VALUES ('London', 'United Kingdom', 'Summer',15.7,157.0)")
cur.execute("INSERT INTO Weatherr VALUES ('London', 'United Kingdom', 'Fall',10.4,218.5)")
cur.execute("INSERT INTO Weatherr VALUES ('Cairo', 'Egypt', 'Winter',13.6,16.5)")
cur.execute("INSERT INTO Weatherr VALUES ('Cairo', 'Egypt', 'Spring',20.7,6.5)")
cur.execute("INSERT INTO Weatherr VALUES ('Cairo', 'Egypt', 'Summer',27.7,0.1)")
cur.execute("INSERT INTO Weatherr VALUES ('Cairo', 'Egypt', 'Fall',22.2,4.5)")

# %%
cur.execute('SELECT * FROM Weatherr')
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute('SELECT temperature FROM Weatherr')
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute('SELECT DISTINCT City FROM Weatherr')
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute("SELECT * FROM Weatherr WHERE Country='India'")
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute("SELECT * FROM Weatherr WHERE Season='Fall'")
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute("SELECT City,country,Season FROM Weatherr WHERE Rainfall BETWEEN 200 AND 400")
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute("SELECT City,country FROM Weatherr WHERE Season='Fall' AND temperature > 20 ORDER BY temperature ASC")
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute("SELECT SUM(Rainfall) FROM Weatherr WHERE City='Cairo'")
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cur.execute("SELECT SUM(Rainfall) FROM Weatherr GROUP BY Season")
cur.fetchall()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#question 9
x = list('The quick brown fox jumps over the lazy dog'.split())

# %%
one = [i.upper() for i in x]
two = [i.lower() for i in x]
three = [len(i) for i in x]
four = [[i.upper(),i.lower(),len(i)] for i in x]
five = [i for i in x if len(i) >= 4]

# %%
print(one)
print(two)
print(three)
print(four)
print(five)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
